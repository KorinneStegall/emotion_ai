# %% [markdown]
# ## PART 1 - Key Facial Points Detection
# Creating a deep learning model based on Convolutional Neural Networks and Residual Blocks to predict facial key-points.

# %%
# # Importing libraries
# import pandas as pd
# import numpy as np
# import os
# import PIL
# import seaborn as sns
# import pickle
# from PIL import *
# import cv2
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.applications import DenseNet121
# from tensorflow.keras.models import Model, load_model
# from tensorflow.keras.initializers import glorot_uniform
# from tensorflow.keras.utils import plot_model
# from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
# from IPython.display import display
# from tensorflow.python.keras import *
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras import layers, optimizers
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.layers import *
# from tensorflow.keras import backend as K
# from keras import optimizers
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import pickle
from PIL import Image
import cv2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# load in key facial data points
keyfacial_df = pd.read_csv("data.csv")
keyfacial_df.head(2)
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# 1                70.722723                36.187166                 36.034723
#
#    right_eye_inner_corner_y  ...  nose_tip_y  mouth_left_corner_x  \
# 0                 37.389402  ...   57.066803            61.195308
# 1                 34.361532  ...   55.660936            56.421447
#
#    mouth_left_corner_y  mouth_right_corner_x  mouth_right_corner_y  \
# 0            79.970165             28.614496             77.388992
# 1            76.352000             35.122383             76.047660
#
#    mouth_center_top_lip_x  mouth_center_top_lip_y  mouth_center_bottom_lip_x  \
# 0               43.312602               72.935459                  43.130707
# 1               46.684596               70.266553                  45.467915
#
#    mouth_center_bottom_lip_y  \
# 0                  84.485774
# 1                  85.480170
#
#                                                Image
# 0  238 236 237 238 240 240 239 241 241 243 240 23...
# 1  219 215 204 196 204 211 212 200 180 168 178 19...
#
# [2 rows x 31 columns]

# %% [markdown]
# ***

# %% [markdown]
# <br>

# %% [markdown]
# ### Exploratory Analysis and Data Cleaning

# %%
# Obtain relevant information about dataframe
keyfacial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2140 entries, 0 to 2139
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   left_eye_center_x          2140 non-null   float64
#  1   left_eye_center_y          2140 non-null   float64
#  2   right_eye_center_x         2140 non-null   float64
#  3   right_eye_center_y         2140 non-null   float64
#  4   left_eye_inner_corner_x    2140 non-null   float64
#  5   left_eye_inner_corner_y    2140 non-null   float64
#  6   left_eye_outer_corner_x    2140 non-null   float64
#  7   left_eye_outer_corner_y    2140 non-null   float64
#  8   right_eye_inner_corner_x   2140 non-null   float64
#  9   right_eye_inner_corner_y   2140 non-null   float64
#  10  right_eye_outer_corner_x   2140 non-null   float64
#  11  right_eye_outer_corner_y   2140 non-null   float64
#  12  left_eyebrow_inner_end_x   2140 non-null   float64
#  13  left_eyebrow_inner_end_y   2140 non-null   float64
#  14  left_eyebrow_outer_end_x   2140 non-null   float64
#  15  left_eyebrow_outer_end_y   2140 non-null   float64
#  16  right_eyebrow_inner_end_x  2140 non-null   float64
#  17  right_eyebrow_inner_end_y  2140 non-null   float64
#  18  right_eyebrow_outer_end_x  2140 non-null   float64
#  19  right_eyebrow_outer_end_y  2140 non-null   float64
#  20  nose_tip_x                 2140 non-null   float64
#  21  nose_tip_y                 2140 non-null   float64
#  22  mouth_left_corner_x        2140 non-null   float64
#  23  mouth_left_corner_y        2140 non-null   float64
#  24  mouth_right_corner_x       2140 non-null   float64
#  25  mouth_right_corner_y       2140 non-null   float64
#  26  mouth_center_top_lip_x     2140 non-null   float64
#  27  mouth_center_top_lip_y     2140 non-null   float64
#  28  mouth_center_bottom_lip_x  2140 non-null   float64
#  29  mouth_center_bottom_lip_y  2140 non-null   float64
#  30  Image                      2140 non-null   object
# dtypes: float64(30), object(1)
# memory usage: 518.4+ KB

# %%
# Checking for null values
keyfacial_df.isnull().sum()
# Out:
# left_eye_center_x            0
# left_eye_center_y            0
# right_eye_center_x           0
# right_eye_center_y           0
# left_eye_inner_corner_x      0
# left_eye_inner_corner_y      0
# left_eye_outer_corner_x      0
# left_eye_outer_corner_y      0
# right_eye_inner_corner_x     0
# right_eye_inner_corner_y     0
# right_eye_outer_corner_x     0
# right_eye_outer_corner_y     0
# left_eyebrow_inner_end_x     0
# left_eyebrow_inner_end_y     0
# left_eyebrow_outer_end_x     0
# left_eyebrow_outer_end_y     0
# right_eyebrow_inner_end_x    0
# right_eyebrow_inner_end_y    0
# right_eyebrow_outer_end_x    0
# right_eyebrow_outer_end_y    0
# nose_tip_x                   0
# nose_tip_y                   0
# mouth_left_corner_x          0
# mouth_left_corner_y          0
# mouth_right_corner_x         0
# mouth_right_corner_y         0
# mouth_center_top_lip_x       0
# mouth_center_top_lip_y       0
# mouth_center_bottom_lip_x    0
# mouth_center_bottom_lip_y    0
# Image                        0
# dtype: int64

# %%
# Size of datafram
keyfacial_df['Image'].shape
# Out:
# (2140,)

# %%
# Reshaping data --> since values for the image are given as space seperated string, the values need to be reseparated using a space: ' '.
# The data is then converted into a 1d numpy array which then is reshaped into a 2d array with a size of 96 by 96 pixels (the dimensions of the image)
keyfacial_df['Image'] = keyfacial_df['Image'].apply(lambda x: np.fromstring(x, dtype = int, sep = ' ').reshape(96,96))

# %%
# Confirming the dimensions
keyfacial_df['Image'][0].shape
# Out:
# (96, 96)

# %%
# Looking at the statistical summary of the dataframe
keyfacial_df.describe()
# Out:
#        left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# count        2140.000000        2140.000000         2140.000000
# mean           66.221549          36.842274           29.640269
# std             2.087683           2.294027            2.051575
# min            47.835757          23.832996           18.922611
# 25%            65.046300          35.468842           28.472224
# 50%            66.129065          36.913319           29.655440
# 75%            67.332093          38.286438           30.858673
# max            78.013082          46.132421           42.495172
#
#        right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# count         2140.000000              2140.000000              2140.000000
# mean            37.063815                59.272128                37.856014
# std              2.234334                 2.005631                 2.034500
# min             24.773072                41.779381                27.190098
# 25%             35.818377                58.113054                36.607950
# 50%             37.048085                59.327154                37.845220
# 75%             38.333884                60.521492                39.195431
# max             45.980981                69.023030                47.190316
#
#        left_eye_outer_corner_x  left_eye_outer_corner_y  \
# count              2140.000000              2140.000000
# mean                 73.412473                37.640110
# std                   2.701639                 2.684162
# min                  52.947144                26.250023
# 25%                  71.741978                36.102409
# 50%                  73.240045                37.624207
# 75%                  74.978684                39.308331
# max                  87.032252                49.653825
#
#        right_eye_inner_corner_x  right_eye_inner_corner_y  ...   nose_tip_x  \
# count               2140.000000               2140.000000  ...  2140.000000
# mean                  36.603107                 37.920852  ...    47.952141
# std                    1.822784                  2.009505  ...     3.276053
# min                   24.112624                 26.250023  ...    24.472590
# 25%                   35.495730                 36.766783  ...    46.495330
# 50%                   36.620735                 37.920336  ...    47.900511
# 75%                   37.665280                 39.143921  ...    49.260657
# max                   47.293746                 44.887301  ...    65.279654
#
#         nose_tip_y  mouth_left_corner_x  mouth_left_corner_y  \
# count  2140.000000          2140.000000          2140.000000
# mean     57.253926            63.419076            75.887660
# std       4.528635             3.650131             4.438565
# min      41.558400            43.869480            57.023258
# 25%      54.466000            61.341291            72.874263
# 50%      57.638582            63.199057            75.682465
# 75%      60.303524            65.302398            78.774969
# max      75.992731            84.767123            94.673637
#
#        mouth_right_corner_x  mouth_right_corner_y  mouth_center_top_lip_x  \
# count           2140.000000           2140.000000             2140.000000
# mean              32.967365             76.134065               48.081325
# std                3.595103              4.259514                2.723274
# min                9.778137             56.690208               32.260312
# 25%               30.879288             73.280038               46.580004
# 50%               33.034022             75.941985               47.939031
# 75%               35.063575             78.884031               49.290000
# max               50.973348             93.443176               61.804506
#
#        mouth_center_top_lip_y  mouth_center_bottom_lip_x  \
# count             2140.000000                2140.000000
# mean                72.681125                  48.149654
# std                  5.108675                   3.032389
# min                 56.719043                  33.047605
# 25%                 69.271669                  46.492000
# 50%                 72.395978                  47.980854
# 75%                 75.840286                  49.551936
# max                 93.916338                  62.438095
#
#        mouth_center_bottom_lip_y
# count                2140.000000
# mean                   82.630412
# std                     4.813557
# min                    57.232296
# 25%                    79.417480
# 50%                    82.388899
# 75%                    85.697976
# max                    95.808983
#
# [8 rows x 30 columns]

# %% [markdown]
# ***

# %% [markdown]
# <br>

# %% [markdown]
# ### Preforming Image Visualization

# %%
# Plotting a random image from the dataset along its corresponding facial keypoints

# Selecting a random row
i = np.random.randint(1, len(keyfacial_df))
# Plotting row i's associated image
plt.imshow(keyfacial_df['Image'][i], cmap = 'gray')
# Looping through i by steps of 2 to map the x and y coordinates of each facial keypoint
for j in range(1, 31, 2):
    plt.plot(keyfacial_df.loc[i][j-1], keyfacial_df.loc[i][j], 'rx')

# %%
# Plotting more images in a 4x4 grid

fig = plt.figure(figsize=(20, 20))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1)
    image = plt.imshow(keyfacial_df['Image'][i], cmap = 'gray')
    for j in range(1, 31, 2):
        plt.plot(keyfacial_df.loc[i][j-1], keyfacial_df.loc[i][j], 'rx')

# %%
# Sanity check on the data

fig = plt.figure(figsize=(20, 20))

for j in range(64):
    i = np.random.randint(1, len(keyfacial_df))
    ax = fig.add_subplot(8, 8, j + 1)
    image = plt.imshow(keyfacial_df['Image'][i], cmap = 'gray')
    for k in range(1, 31, 2):
        plt.plot(keyfacial_df.loc[i][k-1], keyfacial_df.loc[i][k], 'rx')

# %% [markdown]
# ***

# %% [markdown]
# <br>

# %% [markdown]
# ### Preform Image Augmentation

# %%
# Creating a copy of the dataframe 
import copy
keyfacial_df_copy = copy.copy(keyfacial_df)

# The copy will include a varied version of the original's images to improve the model's generalibility

# %%
# Obtaining the columns in the dataframe besides the image portion
columns = keyfacial_df_copy.columns[:-1]
columns
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'left_eye_inner_corner_x',
#        'left_eye_inner_corner_y', 'left_eye_outer_corner_x',
#        'left_eye_outer_corner_y', 'right_eye_inner_corner_x',
#        'right_eye_inner_corner_y', 'right_eye_outer_corner_x',
#        'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x',
#        'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x',
#        'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x',
#        'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x',
#        'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y',
#        'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x',
#        'mouth_right_corner_y', 'mouth_center_top_lip_x',
#        'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x',
#        'mouth_center_bottom_lip_y'],
#       dtype='object')

# %%
# Horizontally flipping the images (mirroring)
keyfacial_df_copy['Image'] = keyfacial_df_copy['Image'].apply(lambda x: np.flip(x, axis=1))

# Adjusting the x coordinates to the mirrored images (y coordinates stay the same)
for i in range(len(columns)):
    if i%2 == 0:
        keyfacial_df_copy[columns[i]] = keyfacial_df_copy[columns[i]].apply(lambda x: 96. - float(x)) 
        # Flipping the coordinate is achieved by subtracting the original number by the width of the image i.e. 96 pixels.

# %%
# Original image
plt.imshow(keyfacial_df['Image'][0], cmap = 'gray')
for j in range(1, 31, 2):
    plt.plot(keyfacial_df.loc[0][j-1], keyfacial_df.loc[0][j], 'rx')

# %%
# Flipping image
plt.imshow(keyfacial_df_copy['Image'][0], cmap = 'gray')
for j in range(1, 31, 2):
    plt.plot(keyfacial_df_copy.loc[0][j-1], keyfacial_df_copy.loc[0][j], 'rx')

# %%
# Concatenate the original dataframe with the flipped dataframe
augmented_df = np.concatenate((keyfacial_df, keyfacial_df_copy))
augmented_df.shape
# Out:
# (4280, 31)

# %%
# Increasing the brightness of random images 
#This is achieved by multiplying pixel values between 1.5 and 2, and clipping the value between 0 and 255

keyfacial_df_copy = copy.copy(keyfacial_df)
keyfacial_df_copy['Image'] = keyfacial_df_copy['Image'].apply(lambda x: np.clip(np.random.uniform(1.5, 2) * x, 0.0, 255.0))

# Confirming changes
fig = plt.figure(figsize=(20, 20))
for i in range(4):
    j = np.random.randint(1, len(keyfacial_df))
    ax = fig.add_subplot(1, 4, i + 1)
    image = plt.imshow(keyfacial_df_copy['Image'][j], cmap = 'gray')
    for k in range(1, 31, 2):
        plt.plot(keyfacial_df_copy.loc[j][k-1], keyfacial_df_copy.loc[j][k], 'rx')

# %%
# Adding the new images
augmented_df = np.concatenate((augmented_df, keyfacial_df_copy))
augmented_df.shape
# Out:
# (6420, 31)

# %%
# Vertically flipping the images 
keyfacial_df_copy = copy.copy(keyfacial_df)
keyfacial_df_copy['Image'] = keyfacial_df_copy['Image'].apply(lambda x: np.flip(x, axis=0))

# Adjusting the y coordinates to the flipped images (x coordinates stay the same)
for i in range(len(columns)):
    if i%2 == 1:
        keyfacial_df_copy[columns[i]] = keyfacial_df_copy[columns[i]].apply(lambda x: 96. - float(x)) 
        # Flipping the coordinate is achieved by subtracting the original number by the heighth of the image i.e. 96 pixels.

plt.imshow(keyfacial_df_copy['Image'][0], cmap = 'gray')
for j in range(1, 31, 2):
    plt.plot(keyfacial_df_copy.loc[0][j-1], keyfacial_df_copy.loc[0][j], 'rx')

# %%
# Adding changes
augmented_df = np.concatenate((augmented_df, keyfacial_df_copy))
augmented_df.shape
# Out:
# (8560, 31)

# %% [markdown]
# ***

# %% [markdown]
# <br>

# %% [markdown]
# ### Preform Data Normalization and Training Data Preparation

# %%
# Input

# Storing all images from augmented_df into a list called img
img = augmented_df[:, 30]

# Normalizing the images
img = img/255. #dividing by 255 scales down the pixel values to a range between 0 and 1

# Creating an empy array of shape (x, 96, 96, 1) to feed the model
X = np.empty((len(img), 96, 96, 1))

# Converting the img list dimensions to match those of array X and adding the values
for i in range(len(img)):
    X[i,] = np.expand_dims(img[i], axis = 2)

# Converting type to float32
X = np.asarray(X).astype(np.float32)
X.shape
# Out:
# (8560, 96, 96, 1)

# %%
# Output

# Obtaining the value of x and y coordinates
y = augmented_df[:, :30]
y = np.asarray(y).astype(np.float32)
y.shape
# Out:
# (8560, 30)

# %%
# Splitting the data into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4)

print(X_train.shape)
print(X_test.shape)
# Out:
# (5136, 96, 96, 1)
# (3424, 96, 96, 1)

# %% [markdown]
# ***

# %% [markdown]
# <br>

# %% [markdown]
# ### Build Deep Residual Neural Network Key Facial Points Detection Model

# %%
def res_block(X, filter, stage):
    # Convolutional_Block
    X_copy = X
    
    f1, f2, f3 = filter
    
    # Main path
    X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
    #X = MaxPool2D((2,2))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name = 'res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(f3, kernel_size = (1,1), strides =(1,1), name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)
    
    #Short path
    X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1), name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
    #X_copy = MaxPool2D((2,2))(X_copy)
    X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)
    
    #ADD
    X = Add()([X,X_copy])
    X = Activation('relu')(X)
    
    
    #Identity_Block_1
    X_copy = X
    
    #Main path
    X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(f2, kernel_size = (3,3),strides = (1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(f3, kernel_size = (1,1), strides = (1,1), name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)
    
    #ADD
    X = Add()([X,X_copy])
    X = Activation('relu')(X)
    
    
    #Identity_Block_2
    X_copy = X
    
    #Main path
    X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(f2, kernel_size = (3,3),strides = (1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(f3, kernel_size = (1,1), strides = (1,1), name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)
    
    #ADD
    X = Add()([X,X_copy])
    X = Activation('relu')(X)
    
    return X

# %%
input_shape = (96, 96, 1)

# Input tensor shape
X_input = Input(input_shape)

# Zero-padding
X = ZeroPadding2D((3,3))(X_input)

# 1 - stage
X = Conv2D(64, (7,7), strides= (2,2), name= 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
X = BatchNormalization(axis= 3, name= 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3,3), strides= (2,2))(X)

# 2 - stage
X = res_block(X, filter= [64, 64, 256], stage= 2)

# 3 - stage
X = res_block(X, filter= [128, 128, 512], stage= 3)

# 4 - stage
X = res_block(X, filter= [256, 256, 1024], stage= 4)

# Average Pooling
X = AveragePooling2D((2,2), name= 'Average_Pooling')(X)

#Final Layer
X = Flatten()(X)
X = Dense(4096, activation= 'relu')(X)
X = Dropout(0.2)(X)
X = Dense(2048, activation= 'relu')(X)
X = Dropout(0.1)(X)
X = Dense(30, activation= 'relu')(X)


model_1_facialKeyPoints = Model( inputs= X_input, outputs = X)
model_1_facialKeyPoints.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 96, 96, 1)]          0         []
#
#  zero_padding2d_1 (ZeroPadd  (None, 102, 102, 1)          0         ['input_3[0][0]']
#  ing2D)
#
#  conv1 (Conv2D)              (None, 48, 48, 64)           3200      ['zero_padding2d_1[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 48, 48, 64)           256       ['conv1[0][0]']
#  on)
#
#  activation_19 (Activation)  (None, 48, 48, 64)           0         ['bn_conv1[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 23, 23, 64)           0         ['activation_19[0][0]']
#  g2D)
#
#  res_2_conv_a (Conv2D)       (None, 23, 23, 64)           4160      ['max_pooling2d_5[0][0]']
#
#  bn_2_conv_a (BatchNormaliz  (None, 23, 23, 64)           256       ['res_2_conv_a[0][0]']
#  ation)
#
#  activation_20 (Activation)  (None, 23, 23, 64)           0         ['bn_2_conv_a[0][0]']
#
#  res_2_conv_b (Conv2D)       (None, 23, 23, 64)           36928     ['activation_20[0][0]']
#
#  bn_2_conv_b (BatchNormaliz  (None, 23, 23, 64)           256       ['res_2_conv_b[0][0]']
#  ation)
#
#  activation_21 (Activation)  (None, 23, 23, 64)           0         ['bn_2_conv_b[0][0]']
#
#  res_2_conv_c (Conv2D)       (None, 23, 23, 256)          16640     ['activation_21[0][0]']
#
#  res_2_conv_copy (Conv2D)    (None, 23, 23, 256)          16640     ['max_pooling2d_5[0][0]']
#
#  bn_2_conv_c (BatchNormaliz  (None, 23, 23, 256)          1024      ['res_2_conv_c[0][0]']
#  ation)
#
#  bn_2_conv_copy (BatchNorma  (None, 23, 23, 256)          1024      ['res_2_conv_copy[0][0]']
#  lization)
#
#  add_6 (Add)                 (None, 23, 23, 256)          0         ['bn_2_conv_c[0][0]',
#                                                                      'bn_2_conv_copy[0][0]']
#
#  activation_22 (Activation)  (None, 23, 23, 256)          0         ['add_6[0][0]']
#
#  res_2_identity_1_a (Conv2D  (None, 23, 23, 64)           16448     ['activation_22[0][0]']
#  )
#
#  bn_2_identity_1_a (BatchNo  (None, 23, 23, 64)           256       ['res_2_identity_1_a[0][0]']
#  rmalization)
#
#  activation_23 (Activation)  (None, 23, 23, 64)           0         ['bn_2_identity_1_a[0][0]']
#
#  res_2_identity_1_b (Conv2D  (None, 23, 23, 64)           36928     ['activation_23[0][0]']
#  )
#
#  bn_2_identity_1_b (BatchNo  (None, 23, 23, 64)           256       ['res_2_identity_1_b[0][0]']
#  rmalization)
#
#  activation_24 (Activation)  (None, 23, 23, 64)           0         ['bn_2_identity_1_b[0][0]']
#
#  res_2_identity_1_c (Conv2D  (None, 23, 23, 256)          16640     ['activation_24[0][0]']
#  )
#
#  bn_2_identity_1_c (BatchNo  (None, 23, 23, 256)          1024      ['res_2_identity_1_c[0][0]']
#  rmalization)
#
#  add_7 (Add)                 (None, 23, 23, 256)          0         ['bn_2_identity_1_c[0][0]',
#                                                                      'activation_22[0][0]']
#
#  activation_25 (Activation)  (None, 23, 23, 256)          0         ['add_7[0][0]']
#
#  res_2_identity_2_a (Conv2D  (None, 23, 23, 64)           16448     ['activation_25[0][0]']
#  )
#
#  bn_2_identity_2_a (BatchNo  (None, 23, 23, 64)           256       ['res_2_identity_2_a[0][0]']
#  rmalization)
#
#  activation_26 (Activation)  (None, 23, 23, 64)           0         ['bn_2_identity_2_a[0][0]']
#
#  res_2_identity_2_b (Conv2D  (None, 23, 23, 64)           36928     ['activation_26[0][0]']
#  )
#
#  bn_2_identity_2_b (BatchNo  (None, 23, 23, 64)           256       ['res_2_identity_2_b[0][0]']
#  rmalization)
#
#  activation_27 (Activation)  (None, 23, 23, 64)           0         ['bn_2_identity_2_b[0][0]']
#
#  res_2_identity_2_c (Conv2D  (None, 23, 23, 256)          16640     ['activation_27[0][0]']
#  )
#
#  bn_2_identity_2_c (BatchNo  (None, 23, 23, 256)          1024      ['res_2_identity_2_c[0][0]']
#  rmalization)
#
#  add_8 (Add)                 (None, 23, 23, 256)          0         ['bn_2_identity_2_c[0][0]',
#                                                                      'activation_25[0][0]']
#
#  activation_28 (Activation)  (None, 23, 23, 256)          0         ['add_8[0][0]']
#
#  res_3_conv_a (Conv2D)       (None, 23, 23, 128)          32896     ['activation_28[0][0]']
#
#  bn_3_conv_a (BatchNormaliz  (None, 23, 23, 128)          512       ['res_3_conv_a[0][0]']
#  ation)
#
#  activation_29 (Activation)  (None, 23, 23, 128)          0         ['bn_3_conv_a[0][0]']
#
#  res_3_conv_b (Conv2D)       (None, 23, 23, 128)          147584    ['activation_29[0][0]']
#
#  bn_3_conv_b (BatchNormaliz  (None, 23, 23, 128)          512       ['res_3_conv_b[0][0]']
#  ation)
#
#  activation_30 (Activation)  (None, 23, 23, 128)          0         ['bn_3_conv_b[0][0]']
#
#  res_3_conv_c (Conv2D)       (None, 23, 23, 512)          66048     ['activation_30[0][0]']
#
#  res_3_conv_copy (Conv2D)    (None, 23, 23, 512)          131584    ['activation_28[0][0]']
#
#  bn_3_conv_c (BatchNormaliz  (None, 23, 23, 512)          2048      ['res_3_conv_c[0][0]']
#  ation)
#
#  bn_3_conv_copy (BatchNorma  (None, 23, 23, 512)          2048      ['res_3_conv_copy[0][0]']
#  lization)
#
#  add_9 (Add)                 (None, 23, 23, 512)          0         ['bn_3_conv_c[0][0]',
#                                                                      'bn_3_conv_copy[0][0]']
#
#  activation_31 (Activation)  (None, 23, 23, 512)          0         ['add_9[0][0]']
#
#  res_3_identity_1_a (Conv2D  (None, 23, 23, 128)          65664     ['activation_31[0][0]']
#  )
#
#  bn_3_identity_1_a (BatchNo  (None, 23, 23, 128)          512       ['res_3_identity_1_a[0][0]']
#  rmalization)
#
#  activation_32 (Activation)  (None, 23, 23, 128)          0         ['bn_3_identity_1_a[0][0]']
#
#  res_3_identity_1_b (Conv2D  (None, 23, 23, 128)          147584    ['activation_32[0][0]']
#  )
#
#  bn_3_identity_1_b (BatchNo  (None, 23, 23, 128)          512       ['res_3_identity_1_b[0][0]']
#  rmalization)
#
#  activation_33 (Activation)  (None, 23, 23, 128)          0         ['bn_3_identity_1_b[0][0]']
#
#  res_3_identity_1_c (Conv2D  (None, 23, 23, 512)          66048     ['activation_33[0][0]']
#  )
#
#  bn_3_identity_1_c (BatchNo  (None, 23, 23, 512)          2048      ['res_3_identity_1_c[0][0]']
#  rmalization)
#
#  add_10 (Add)                (None, 23, 23, 512)          0         ['bn_3_identity_1_c[0][0]',
#                                                                      'activation_31[0][0]']
#
#  activation_34 (Activation)  (None, 23, 23, 512)          0         ['add_10[0][0]']
#
#  res_3_identity_2_a (Conv2D  (None, 23, 23, 128)          65664     ['activation_34[0][0]']
#  )
#
#  bn_3_identity_2_a (BatchNo  (None, 23, 23, 128)          512       ['res_3_identity_2_a[0][0]']
#  rmalization)
#
#  activation_35 (Activation)  (None, 23, 23, 128)          0         ['bn_3_identity_2_a[0][0]']
#
#  res_3_identity_2_b (Conv2D  (None, 23, 23, 128)          147584    ['activation_35[0][0]']
#  )
#
#  bn_3_identity_2_b (BatchNo  (None, 23, 23, 128)          512       ['res_3_identity_2_b[0][0]']
#  rmalization)
#
#  activation_36 (Activation)  (None, 23, 23, 128)          0         ['bn_3_identity_2_b[0][0]']
#
#  res_3_identity_2_c (Conv2D  (None, 23, 23, 512)          66048     ['activation_36[0][0]']
#  )
#
#  bn_3_identity_2_c (BatchNo  (None, 23, 23, 512)          2048      ['res_3_identity_2_c[0][0]']
#  rmalization)
#
#  add_11 (Add)                (None, 23, 23, 512)          0         ['bn_3_identity_2_c[0][0]',
#                                                                      'activation_34[0][0]']
#
#  activation_37 (Activation)  (None, 23, 23, 512)          0         ['add_11[0][0]']
#
#  res_4_conv_a (Conv2D)       (None, 23, 23, 256)          131328    ['activation_37[0][0]']
#
#  bn_4_conv_a (BatchNormaliz  (None, 23, 23, 256)          1024      ['res_4_conv_a[0][0]']
#  ation)
#
#  activation_38 (Activation)  (None, 23, 23, 256)          0         ['bn_4_conv_a[0][0]']
#
#  res_4_conv_b (Conv2D)       (None, 23, 23, 256)          590080    ['activation_38[0][0]']
#
#  bn_4_conv_b (BatchNormaliz  (None, 23, 23, 256)          1024      ['res_4_conv_b[0][0]']
#  ation)
#
#  activation_39 (Activation)  (None, 23, 23, 256)          0         ['bn_4_conv_b[0][0]']
#
#  res_4_conv_c (Conv2D)       (None, 23, 23, 1024)         263168    ['activation_39[0][0]']
#
#  res_4_conv_copy (Conv2D)    (None, 23, 23, 1024)         525312    ['activation_37[0][0]']
#
#  bn_4_conv_c (BatchNormaliz  (None, 23, 23, 1024)         4096      ['res_4_conv_c[0][0]']
#  ation)
#
#  bn_4_conv_copy (BatchNorma  (None, 23, 23, 1024)         4096      ['res_4_conv_copy[0][0]']
#  lization)
#
#  add_12 (Add)                (None, 23, 23, 1024)         0         ['bn_4_conv_c[0][0]',
#                                                                      'bn_4_conv_copy[0][0]']
#
#  activation_40 (Activation)  (None, 23, 23, 1024)         0         ['add_12[0][0]']
#
#  res_4_identity_1_a (Conv2D  (None, 23, 23, 256)          262400    ['activation_40[0][0]']
#  )
#
#  bn_4_identity_1_a (BatchNo  (None, 23, 23, 256)          1024      ['res_4_identity_1_a[0][0]']
#  rmalization)
#
#  activation_41 (Activation)  (None, 23, 23, 256)          0         ['bn_4_identity_1_a[0][0]']
#
#  res_4_identity_1_b (Conv2D  (None, 23, 23, 256)          590080    ['activation_41[0][0]']
#  )
#
#  bn_4_identity_1_b (BatchNo  (None, 23, 23, 256)          1024      ['res_4_identity_1_b[0][0]']
#  rmalization)
#
#  activation_42 (Activation)  (None, 23, 23, 256)          0         ['bn_4_identity_1_b[0][0]']
#
#  res_4_identity_1_c (Conv2D  (None, 23, 23, 1024)         263168    ['activation_42[0][0]']
#  )
#
#  bn_4_identity_1_c (BatchNo  (None, 23, 23, 1024)         4096      ['res_4_identity_1_c[0][0]']
#  rmalization)
#
#  add_13 (Add)                (None, 23, 23, 1024)         0         ['bn_4_identity_1_c[0][0]',
#                                                                      'activation_40[0][0]']
#
#  activation_43 (Activation)  (None, 23, 23, 1024)         0         ['add_13[0][0]']
#
#  res_4_identity_2_a (Conv2D  (None, 23, 23, 256)          262400    ['activation_43[0][0]']
#  )
#
#  bn_4_identity_2_a (BatchNo  (None, 23, 23, 256)          1024      ['res_4_identity_2_a[0][0]']
#  rmalization)
#
#  activation_44 (Activation)  (None, 23, 23, 256)          0         ['bn_4_identity_2_a[0][0]']
#
#  res_4_identity_2_b (Conv2D  (None, 23, 23, 256)          590080    ['activation_44[0][0]']
#  )
#
#  bn_4_identity_2_b (BatchNo  (None, 23, 23, 256)          1024      ['res_4_identity_2_b[0][0]']
#  rmalization)
#
#  activation_45 (Activation)  (None, 23, 23, 256)          0         ['bn_4_identity_2_b[0][0]']
#
#  res_4_identity_2_c (Conv2D  (None, 23, 23, 1024)         263168    ['activation_45[0][0]']
#  )
#
#  bn_4_identity_2_c (BatchNo  (None, 23, 23, 1024)         4096      ['res_4_identity_2_c[0][0]']
#  rmalization)
#
#  add_14 (Add)                (None, 23, 23, 1024)         0         ['bn_4_identity_2_c[0][0]',
#                                                                      'activation_43[0][0]']
#
#  activation_46 (Activation)  (None, 23, 23, 1024)         0         ['add_14[0][0]']
#
#  Average_Pooling (AveragePo  (None, 11, 11, 1024)         0         ['activation_46[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)         (None, 123904)               0         ['Average_Pooling[0][0]']
#
#  dense_3 (Dense)             (None, 4096)                 5075148   ['flatten_1[0][0]']
#                                                           80
#
#  dropout_2 (Dropout)         (None, 4096)                 0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 2048)                 8390656   ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 2048)                 0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 30)                   61470     ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 520902174 (1.94 GB)
# Trainable params: 520882334 (1.94 GB)
# Non-trainable params: 19840 (77.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Compile and Train Key Facial Points Detection Deep Learning Model
